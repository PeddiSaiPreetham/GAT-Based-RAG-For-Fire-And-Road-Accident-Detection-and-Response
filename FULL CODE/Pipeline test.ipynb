# %%
# !pip install -r requirements.txt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 75.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [twilio]2m7/8 [twilio]eometric]
# ...

# %%
#1_build_faiss_index
# !python -c "from modules.retriever import Retriever; r = Retriever(index_path='data/faiss_index.bin'); r.build_index('demo_data/guidelines')"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [Retriever] Building embeddings for 12 documents...
# [Retriever] Saving FAISS index → data/faiss_index.bin
# [Retriever] Saving docs → data/docs.pkl
# [Retriever] Index build complete ✔

# %%
from modules.retriever import Retriever
r = Retriever(index_path="data/faiss_index.bin", docs_path="demo_data/guidelines")
r.load_index("data/faiss_index.bin")

print(r.query("What to do during a fire?", k=3))
# Out:
# [Retriever] Loading FAISS index from data/faiss_index.bin
# [Retriever] Loading docs from data/docs.pkl
# ...

# %%
#with audio
# !python test_rag_pipeline.py --config config.yaml --image test_images/panic.jpg #--no_alerts
# Out:
# [2025-12-03 11:45:41,716] INFO - Running on device: cpu
# [2025-12-03 11:45:41,743] INFO - Initialized YOLO model: yolov8n
# [2025-12-03 11:45:41,744] INFO - Detector initialized (yolov8n)
# [2025-12-03 11:45:41,744] INFO - Use pytorch device_name: cpu
# [2025-12-03 11:45:41,744] INFO - Load pretrained SentenceTransformer: all-mpnet-base-v2
# [2025-12-03 11:45:42,173] INFO - Loaded docs from docs_dir: demo_data/guidelines
# [2025-12-03 11:45:42,173] INFO - Retriever ready
# [2025-12-03 11:45:42,173] INFO - LLM generator initialized
# hybrid_gnn_checkpoint.pt
# [2025-12-03 11:45:42,225] INFO - Hybrid GNN loaded from hybrid_gnn_checkpoint.pt
# [2025-12-03 11:45:42,225] ERROR - Image not found: test_images/panic.jpg

# %%
# !pip install soundfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.9 MB/s  0:00:00
# ...

# %%
# !python test_rag_pipeline.py --image test_images/fire.jpg --config config.yaml --device cpu
# Out:
# [2025-12-03 16:03:12,849] INFO - Running on device: cpu
# [2025-12-03 16:03:12,880] INFO - Initialized YOLO model: yolov8n
# [2025-12-03 16:03:12,880] INFO - Detector initialized (yolov8n)
# [2025-12-03 16:03:12,881] INFO - Use pytorch device_name: cuda:0
# [2025-12-03 16:03:12,881] INFO - Load pretrained SentenceTransformer: all-mpnet-base-v2
# [2025-12-03 16:03:13,553] INFO - Loaded docs from docs_dir: demo_data/guidelines
# [2025-12-03 16:03:13,553] INFO - Retriever ready
# [2025-12-03 16:03:13,553] INFO - LLM generator initialized
# hybrid_gnn_checkpoint.pt
# [2025-12-03 16:03:13,602] INFO - Hybrid GNN loaded from hybrid_gnn_checkpoint.pt
# [2025-12-03 16:03:13,607] INFO - Loaded image: test_images/fire.jpg  shape=(183, 275, 3)
# [2025-12-03 16:03:13,718] INFO - YOLO detections: 0
# [2025-12-03 16:03:13,750] INFO - GNN probabilities = normal=0.002, fire=0.998, accident=0.000
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  1.96it/s]
#
# ...
